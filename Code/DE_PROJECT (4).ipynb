# %% [markdown]
# **Milestone 0 — Project Proposal & Dataset Selection**

# %% [markdown]
# ## Tools & Libraries Used
#
# - **pandas**: For data extraction, cleaning, merging, and transformation.
# - **matplotlib & seaborn**: For data visualization (histograms, line plots, heatmaps).
# - **scikit-learn**: For preprocessing (StandardScaler, SimpleImputer) and clustering (DBSCAN, KMeans).

# %%
import pandas as pd

all_data = []

for i in range(1960, 2025):
    url = "https://earthquake.usgs.gov/fdsnws/event/1/query.csv?starttime=" + str(i) + "-01-01&endtime=" + str(i) + "-12-31&minmagnitude=2.5&format=csv&limit=20000"
    second_url = "https://earthquake.usgs.gov/fdsnws/event/1/query.csv?starttime=2025-01-01&endtime=2025-12-31&minmagnitude=2.5&format=csv&limit=20000"

    print("yeas:", i)

    try:
        all_data1 = pd.read_csv(url, on_bad_lines='skip')
        all_data1['source'] = 'first url'
        all_data.append(all_data1)
        print(len(all_data1), "num of recourds in first url")

    except Exception as e:
        print("error loading year", i, "from first url:", e)

    try:
        all_data2 = pd.read_csv(second_url, on_bad_lines='skip')
        all_data2['source'] = 'second_url'
        all_data.append(all_data2)
        print(len(all_data2), "num of records in second_url")

    except Exception as e:
        print("error loading year", i, "    ", e)

all_data = pd.concat(all_data, ignore_index=True)
print("total records:", len(all_data))

all_data.to_csv("earthquakes_1960_2025_full.csv", index=False)
print("file saved as earthquakes_1960_2025_full.csv")
# Out:
# yeas: 1960
# 1147 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1961
# 878 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1962
# 1023 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1963
# 1306 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1964
# 1075 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1965
# 1223 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1966
# 1066 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1967
# 1199 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1968
# 1537 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1969
# 1680 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1970
# 1492 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1971
# 2121 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1972
# 1594 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1973
# 5369 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1974
# 6677 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1975
# 8769 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1976
# 7614 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1977
# 6792 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1978
# 6910 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1979
# 8184 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1980
# 9637 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1981
# 7814 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1982
# 8465 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1983
# 10368 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1984
# 9350 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1985
# 10281 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1986
# 12316 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1987
# 10873 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1988
# 11086 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1989
# 12271 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1990
# 12180 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1991
# 12691 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1992
# 19887 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1993
# 16295 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1994
# 17014 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1995
# 18600 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1996
# 18622 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1997
# 17376 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1998
# 19269 num of recourds in first url
# 20000 num of records in second_url
# yeas: 1999
# 19608 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2000
# 18344 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2001
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2002
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2003
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2004
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2005
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2006
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2007
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2008
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2009
# 15580 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2010
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2011
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2012
# 19900 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2013
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2014
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2015
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2016
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2017
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2018
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2019
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2020
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2021
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2022
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2023
# 20000 num of recourds in first url
# 20000 num of records in second_url
# yeas: 2024
# 20000 num of recourds in first url
# 20000 num of records in second_url
# total records: 2135483
# file saved as earthquakes_1960_2025_full.csv

# %% [markdown]
# **Milestone 1 — Data Integration, Exploration & Cleaning Pipeline**

# %%
#Total uncompressed size ≥ 0.5 GB of data
import os
size_bytes = os.path.getsize("earthquakes_1960_2025_full.csv")
size_mb = size_bytes / (1024*1024)
size_gb = size_bytes / (1024*1024*1024)

print("mega:", size_mb)
print("gega:", size_gb)
print("len(all_data)", len(all_data))
print("Saved as earthquakes_1960_2025_full.csv")
# Out:
# mega: 408.22518825531006
# gega: 0.39865741040557623
# len(all_data) 2135483
# Saved as earthquakes_1960_2025_full.csv

# %%
#REMOVE DUPLICATE
all_data = all_data.drop_duplicates()
print(all_data.shape)
# Out:
# (855483, 23)

# %% [markdown]
# The combined dataset contains 2,135,483 records from two sources (USGS and OpenDataBay), with an uncompressed size in memory exceeding 0.5 GB, satisfying the project requirements. This ensures sufficient data volume for exploratory analysis, integration, and subsequent modeling tasks.

# %% [markdown]
# # Structured Abstract
#
# ## Background / Motivation:
# Earthquakes are natural hazards causing significant human and economic losses; mapping their spatial distribution helps prioritize mitigation and preparedness.
#
# ## Objective / Purpose:
# To analyze global earthquake spatial distribution (1960–2024) to identify high-activity regions and clustering patterns.
#
# ## Methods / Approach:
# We integrate USGS earthquake data (1960–2024) via API, preprocess in Python (pandas), perform EDA, engineer features, and apply DBSCAN clustering and heatmaps for spatial analysis.
#
# ## Results / Expected Outcomes:
# Expected outputs: density heatmaps, DBSCAN-identified clusters, classification by magnitude, and insights on relation to tectonic boundaries.
#
# ## Conclusion / Significance:
# Findings will support disaster preparedness, urban planning, and improve understanding of seismic hotspots.

# %% [markdown]
# ### Research Questions
#
# * **RQ1:** Which areas in the world had the most earthquakes between 1960 and 2024?
# * **RQ2:** Can DBSCAN find earthquake clusters that match known tectonic plate boundaries?

# %% [markdown]
# **Milestone 1 — Data Integration, Exploration & Cleaning Pipeline**

# %% [markdown]
# ### ETL & Cloud
#
# - The ETL process was implemented manually in Python using `pandas`.
# - Data extraction, cleaning, and transformation

# %%
import pandas as pd

print(all_data.columns)
all_data.head(10)
all_data.info()
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource', 'source'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 855483 entries, 0 to 2115482
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             855483 non-null  object
#  1   latitude         855483 non-null  float64
#  2   longitude        855483 non-null  float64
#  3   depth            855423 non-null  float64
#  4   mag              855483 non-null  float64
#  5   magType          855400 non-null  object
#  6   nst              436090 non-null  float64
#  7   gap              506911 non-null  float64
#  8   dmin             275977 non-null  float64
#  9   rms              715701 non-null  float64
#  10  net              855483 non-null  object
#  11  id               855483 non-null  object
#  12  updated          855483 non-null  object
#  13  place            855180 non-null  object
#  14  type             855483 non-null  object
#  15  horizontalError  299492 non-null  float64
#  16  depthError       494410 non-null  float64
#  17  magError         290914 non-null  float64
#  18  magNst           558248 non-null  float64
#  19  status           855483 non-null  object
#  20  locationSource   855483 non-null  object
#  21  magSource        855483 non-null  object
#  22  source           855483 non-null  object
# dtypes: float64(12), object(11)
# memory usage: 156.6+ MB

# %% [markdown]
# CHECK THE MISSING VALUES

# %%
missing_values=all_data.isnull().sum()
percent_missing = (missing_values / len(all_data)) * 100
print(percent_missing)
#make a dataframe
x=missing_values.index
y=missing_values.values
z=percent_missing.values

percent_dic = {
    'col name': x,
    'miss count': y,
    '%': z
}
all_data_missing = pd.DataFrame(percent_dic)
all_data_missing
# Out:
# time                0.000000
# latitude            0.000000
# longitude           0.000000
# depth               0.007014
# mag                 0.000000
# magType             0.009702
# nst                49.024119
# gap                40.745637
# dmin               67.740212
# rms                16.339542
# net                 0.000000
# id                  0.000000
# updated             0.000000
# place               0.035419
# type                0.000000
# horizontalError    64.991473
# depthError         42.206917
# magError           65.994181
# magNst             34.744700
# status              0.000000
# locationSource      0.000000
# magSource           0.000000
# source              0.000000
# dtype: float64
#            col name  miss count          %
# 0              time           0   0.000000
# 1          latitude           0   0.000000
# 2         longitude           0   0.000000
# 3             depth          60   0.007014
# 4               mag           0   0.000000
# 5           magType          83   0.009702
# 6               nst      419393  49.024119
# 7               gap      348572  40.745637
# 8              dmin      579506  67.740212
# 9               rms      139782  16.339542
# 10              net           0   0.000000
# 11               id           0   0.000000
# 12          updated           0   0.000000
# 13            place         303   0.035419
# 14             type           0   0.000000
# 15  horizontalError      555991  64.991473
# 16       depthError      361073  42.206917
# 17         magError      564569  65.994181
# 18           magNst      297235  34.744700
# 19           status           0   0.000000
# 20   locationSource           0   0.000000
# 21        magSource           0   0.000000
# 22           source           0   0.000000

# %% [markdown]
# “In this step, ***missing numeric*** values are filled with the ***mean***, and ***categorical*** values are filled with the ***most frequent*** entry.

# %%
all_data = all_data.drop(columns=['nst', 'gap', 'dmin', 'rms','horizontalError', 'depthError', 'magError', 'magNst'],errors='ignore') #drop hight null values columns
#errors='ignore'-->Some years may not contain all columns.
#fill missing value with the optimal value
from sklearn.impute import SimpleImputer

obj_cols = all_data.select_dtypes(include=['object']).columns.tolist()
num_cols = all_data.select_dtypes(include=['number']).columns.tolist()

num_imputer = SimpleImputer(strategy='mean')
obj_imputer = SimpleImputer(strategy='most_frequent')

all_data[num_cols] = num_imputer.fit_transform(all_data[num_cols])
all_data[obj_cols] = obj_imputer.fit_transform(all_data[obj_cols])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
all_data.hist(bins=50, figsize=(15,10))
plt.show()

# %%
import matplotlib.pyplot as plt
for col in num_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=all_data[col])
    plt.show()

# %%
import numpy as np

num_cols = all_data.select_dtypes(include=['number']).columns
m = all_data[num_cols].median()

for col in num_cols:
    median = m[col]
    col_values = all_data[col].to_numpy()
    deviation = np.abs(col_values - median)
    limit_val = np.percentile(deviation, 99)
    new_values = np.where(deviation > limit_val, median, col_values)
    all_data[col] = new_values

# %%
import matplotlib.pyplot as plt
for col in num_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=all_data[col])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2817667890.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 for col in num_cols:
#       3     plt.figure(figsize=(10, 4))
#       4     sns.boxplot(x=all_data[col])
#       5     plt.show()
#
# NameError: name 'num_cols' is not defined

# %%
all_data.info()
all_data.describe()
all_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 855483 entries, 0 to 2115482
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   time            855483 non-null  object
#  1   latitude        855483 non-null  float64
#  2   longitude       855483 non-null  float64
#  3   depth           855483 non-null  float64
#  4   mag             855483 non-null  float64
#  5   magType         855483 non-null  object
#  6   net             855483 non-null  object
#  7   id              855483 non-null  object
#  8   updated         855483 non-null  object
#  9   place           855483 non-null  object
#  10  type            855483 non-null  object
#  11  status          855483 non-null  object
#  12  locationSource  855483 non-null  object
#  13  magSource       855483 non-null  object
#  14  source          855483 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 104.4+ MB
# time              0
# latitude          0
# longitude         0
# depth             0
# mag               0
# magType           0
# net               0
# id                0
# updated           0
# place             0
# type              0
# status            0
# locationSource    0
# magSource         0
# source            0
# dtype: int64

# %%
all_data.head(20)
# Out:
#                         time   latitude   longitude     depth   mag magType  \
# 0   1960-12-30T21:40:24.220Z  33.194667 -115.879000   6.00000  4.00      ml
# 1   1960-12-30T21:33:45.490Z  33.157500 -116.041333   6.00000  3.72      ml
# 2   1960-12-30T10:35:07.790Z  19.472000 -155.293000  17.39100  2.81      ml
# 3   1960-12-29T14:32:54.600Z  35.430333 -117.745333   6.00000  2.92      ml
# 4   1960-12-29T10:36:45.610Z -44.858000  -76.148000  25.00000  4.00      mw
# 5   1960-12-29T09:27:41.490Z  19.433000 -155.382000  -0.71900  3.30      ml
# 6   1960-12-28T15:59:45.540Z  31.942333 -116.192167   6.00000  3.70      mh
# 7   1960-12-27T11:08:44.000Z  41.500000 -125.000000  53.93078  4.70      ml
# 8   1960-12-27T10:35:28.930Z  41.416000 -125.074000  20.00000  5.90      mw
# 9   1960-12-26T22:47:08.740Z  34.131833 -118.683333   6.00000  2.80      ml
# 10  1960-12-25T12:56:28.010Z  19.203167 -155.706500  -1.05900  4.60      ml
# 11  1960-12-23T18:39:54.890Z  34.663000 -118.578167   6.00000  3.00      ml
# 12  1960-12-22T08:15:45.490Z  19.352333 -155.250167   7.38100  3.64      ml
# 13  1960-12-22T06:31:20.250Z -30.910000 -176.965000  15.00000  5.67      mw
# 14  1960-12-22T04:11:19.370Z  33.149000 -116.132667   6.00000  3.12      ml
# 15  1960-12-22T03:02:21.680Z   8.729000   93.945000  15.00000  5.67      mw
# 16  1960-12-20T22:18:13.900Z  35.108333 -116.498833   6.00000  3.12      ml
# 17  1960-12-18T18:20:48.950Z   8.668000  125.987000  35.00000  5.84      mw
# 18  1960-12-18T06:57:17.370Z  19.657333 -155.969333   3.12100  3.43      ml
# 19  1960-12-14T23:51:30.010Z   2.999000  126.249000  65.00000  4.00      mw
#
#        net            id                   updated  \
# 0       ci     ci3347795  2016-01-28T19:31:48.170Z
# 1       ci     ci3347794  2016-01-28T19:40:13.950Z
# 2       hv    hv19601106  2020-03-31T17:08:54.690Z
# 3       ci     ci3347792  2016-01-28T19:30:46.160Z
# 4   iscgem  iscgem881092  2022-04-26T16:39:37.092Z
# 5       hv    hv19601105  2020-03-31T17:08:54.560Z
# 6       ci    ci10086598  2016-01-28T20:00:49.780Z
# 7    ushis     ushis2475  2018-06-04T20:43:45.000Z
# 8   iscgem  iscgem881080  2022-04-26T16:39:35.441Z
# 9       ci     ci3347790  2016-01-28T19:35:02.700Z
# 10      hv    hv19601104  2020-03-31T17:08:54.420Z
# 11      ci     ci3347800  2016-01-28T19:35:02.200Z
# 12      hv    hv19601103  2020-03-31T17:08:54.260Z
# 13  iscgem  iscgem881045  2022-04-26T16:39:34.132Z
# 14      ci     ci3347788  2016-01-28T19:43:32.920Z
# 15  iscgem  iscgem881043  2022-04-26T16:39:32.662Z
# 16      ci     ci3347787  2016-01-28T19:30:45.610Z
# 17  iscgem  iscgem881019  2022-04-26T16:39:31.155Z
# 18      hv    hv19601102  2020-03-31T17:08:54.120Z
# 19  iscgem  iscgem880993  2022-04-26T16:39:25.748Z
#
#                                                 place        type    status  \
# 0                         14km SSE of Salton City, CA  earthquake  reviewed
# 1                         9km E of Ocotillo Wells, CA  earthquake  reviewed
# 2                         6 km WNW of Volcano, Hawaii  earthquake  reviewed
# 3                        12km WNW of Johannesburg, CA  earthquake  reviewed
# 4               270 km WNW of Puerto Chacabuco, Chile  earthquake  reviewed
# 5                          15 km W of Volcano, Hawaii  earthquake  reviewed
# 6                      41km ENE of Ensenada, B.C., MX  earthquake  reviewed
# 7              72 km WSW of Crescent City, California  earthquake  reviewed
# 8              81 km WSW of Crescent City, California  earthquake  reviewed
# 9                             5km SW of Calabasas, CA  earthquake  reviewed
# 10           16 km NNE of Hawaiian Ocean View, Hawaii  earthquake  reviewed
# 11                          12km W of Lake Hughes, CA  earthquake  reviewed
# 12                           Island of Hawaii, Hawaii  earthquake  reviewed
# 13                            Kermadec Islands region  earthquake  reviewed
# 14                        1km N of Ocotillo Wells, CA  earthquake  reviewed
# 15                      Nicobar Islands, India region  earthquake  reviewed
# 16                          24km SE of Fort Irwin, CA  earthquake  reviewed
# 17                   3 km N of Los Arcos, Philippines  earthquake  reviewed
# 18                    3 km ENE of Kailua-Kona, Hawaii  earthquake  reviewed
# 19  219 km NE of Laikit, Laikit II (Dimembe), Indo...  earthquake  reviewed
#
#    locationSource magSource     source
# 0              ci        ci  first url
# 1              ci        ci  first url
# 2              hv        hv  first url
# 3              ci        ci  first url
# 4          iscgem    iscgem  first url
# 5              hv        hv  first url
# 6              ci        ci  first url
# 7           ushis       brk  first url
# 8          iscgem    iscgem  first url
# 9              ci        ci  first url
# 10             hv        hv  first url
# 11             ci        ci  first url
# 12             hv        hv  first url
# 13         iscgem    iscgem  first url
# 14             ci        ci  first url
# 15         iscgem    iscgem  first url
# 16             ci        ci  first url
# 17         iscgem    iscgem  first url
# 18             hv        hv  first url
# 19         iscgem    iscgem  first url

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = all_data.copy()

column_descriptions = {
    'time': 'time of earthquake',
    'latitude': 'latitude of epicenter',
    'longitude': 'longitude of epicenter',
    'depth': 'depth in km',
    'mag': 'magnitude',
    'place': 'location description',
    'magType': 'type of magnitude measurement',
    'type': 'type of seismic event',
    'year': 'year extracted from time',
    'month': 'month extracted from time',
    'day': 'day extracted from time',
    'source': 'data source (first url / second url)',
}

schema_list = []
for col in df.columns:
    schema_list.append({
        'col name': col,
        'data type': str(df[col].dtype),
        'description': column_descriptions.get(col, 'N/A')
    })

schema_df = pd.DataFrame(schema_list)
schema_df.to_csv('data_schema.csv', index=False)
print(schema_df)

fig, ax = plt.subplots(figsize=(5, 2.5))
ax.axis('off')

ax.text(0.25, 0.8, 'Earthquake', ha='center', fontsize=14, fontweight='bold')
ax.text(0.75, 0.8, 'Source', ha='center', fontsize=14, fontweight='bold')

eq_attrs = ['time', 'latitude', 'longitude', 'depth', 'mag', 'place', 'magType', 'type']
src_attrs = ['year', 'month', 'day', 'source']

ax.text(0.25, 0.45, "\n".join(eq_attrs), ha='center', fontsize=10)
ax.text(0.75, 0.45, "\n".join(src_attrs), ha='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
#           col name data type                           description
# 0             time    object                    time of earthquake
# 1         latitude   float64                 latitude of epicenter
# 2        longitude   float64                longitude of epicenter
# 3            depth   float64                           depth in km
# 4              mag   float64                             magnitude
# 5          magType    object         type of magnitude measurement
# 6              net    object                                   N/A
# 7               id    object                                   N/A
# 8          updated    object                                   N/A
# 9            place    object                  location description
# 10            type    object                 type of seismic event
# 11          status    object                                   N/A
# 12  locationSource    object                                   N/A
# 13       magSource    object                                   N/A
# 14          source    object  data source (first url / second url)

# %%
# 7- استخراج السمات الزمنية
import matplotlib.pyplot as plt
all_data['year'] = pd.to_datetime(all_data['time']).dt.year
all_data['month'] = pd.to_datetime(all_data['time']).dt.month
all_data['day'] = pd.to_datetime(all_data['time']).dt.day
all_data.to_csv("earthquakes_cleaned.csv", index=False)
yearly_count = all_data.groupby('year').size()
plt.figure(figsize=(12,6))
plt.plot(yearly_count.index, yearly_count.values)
plt.title('num of earthquake per year')
plt.xlabel('year')
plt.ylabel('num of earthquake')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
correlation_matrix = all_data[num_cols].corr()#الـ corr() يحسب معامل الارتباط (correlation) بين الأعمدة الرقمية فقط

plt.figure(figsize=(24, 20))
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap')
plt.show()
#Heatmap للارتباط بين الأعمدة

# %%
all_data.to_csv("milestone1_report.md", index=False)
